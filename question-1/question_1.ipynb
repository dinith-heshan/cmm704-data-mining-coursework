# %% [markdown]
# <a href="https://colab.research.google.com/github/dinith-heshan/cmm704-data-mining-coursework/blob/main/question-1/question_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/cmm704-data-mining/question-1
# Out:
# datasets  question-1.ipynb

# %% [markdown]
# # Setup kaggle Dataset in Google Drive

# %% [markdown]
# Upload kaggle API key

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6012b91a-688b-4691-afc0-b3e866e08095" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6012b91a-688b-4691-afc0-b3e866e08095">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Verify Kaggle API key authentication

# %%
# !kaggle datasets list

# %%
# !kaggle competitions list

# %% [markdown]
# Download competition data for Diabetic Retinopathy Detection dataset using kaggle CLI (Not succesful due to running out of RAM available for free tier - Linux OOM kill)

# %%
# !kaggle competitions download -c diabetic-retinopathy-detection -f sample.zip -p /content
# !kaggle competitions download -c diabetic-retinopathy-detection -f sampleSubmission.csv.zip -p /content

# !kaggle competitions download -c diabetic-retinopathy-detection -f test.zip.001 -p /content
# !kaggle competitions download -c diabetic-retinopathy-detection -f test.zip.002 -p /content
# !kaggle competitions download -c diabetic-retinopathy-detection -f test.zip.003 -p /content
# !kaggle competitions download -c diabetic-retinopathy-detection -f test.zip.004 -p /content
# !kaggle competitions download -c diabetic-retinopathy-detection -f test.zip.005 -p /content
# !kaggle competitions download -c diabetic-retinopathy-detection -f test.zip.006 -p /content
# !kaggle competitions download -c diabetic-retinopathy-detection -f test.zip.007 -p /content

# !kaggle competitions download -c diabetic-retinopathy-detection -f train.zip.001 -p /content
# !kaggle competitions download -c diabetic-retinopathy-detection -f train.zip.002 -p /content
# !kaggle competitions download -c diabetic-retinopathy-detection -f train.zip.003 -p /content
# !kaggle competitions download -c diabetic-retinopathy-detection -f train.zip.004 -p /content
# !kaggle competitions download -c diabetic-retinopathy-detection -f train.zip.005 -p /content

# !kaggle competitions download -c diabetic-retinopathy-detection -f trainLabels.csv.zip -p /content

# %% [markdown]
# Setup HTTP authentification token

# %%
# use terminal for setting the following environmental variables

# !export USERNAME=$(python -c "import json;print(json.load(open('/root/.kaggle/kaggle.json'))['username'])")
# !export KEY=$(python -c "import json;print(json.load(open('/root/.kaggle/kaggle.json'))['key'])")

# !export AUTH=$(echo -n "$USERNAME:$KEY" | base64)

# %% [markdown]
# Download the dataset to the Google Colab VM local storage using authenticated HTTP

# %%
# !curl -L -C - -H "Authorization: Basic $AUTH" -o /content/test.zip.001 "https://www.kaggle.com/api/v1/competitions/data/download/diabetic-retinopathy-detection/test.zip.001"
# !curl -L -C - -H "Authorization: Basic $AUTH" -o /content/test.zip.002 "https://www.kaggle.com/api/v1/competitions/data/download/diabetic-retinopathy-detection/test.zip.002"
# !curl -L -C - -H "Authorization: Basic $AUTH" -o /content/test.zip.003 "https://www.kaggle.com/api/v1/competitions/data/download/diabetic-retinopathy-detection/test.zip.003"
# !curl -L -C - -H "Authorization: Basic $AUTH" -o /content/test.zip.004 "https://www.kaggle.com/api/v1/competitions/data/download/diabetic-retinopathy-detection/test.zip.004"
# !curl -L -C - -H "Authorization: Basic $AUTH" -o /content/test.zip.005 "https://www.kaggle.com/api/v1/competitions/data/download/diabetic-retinopathy-detection/test.zip.005"
# !curl -L -C - -H "Authorization: Basic $AUTH" -o /content/test.zip.006 "https://www.kaggle.com/api/v1/competitions/data/download/diabetic-retinopathy-detection/test.zip.006"
# !curl -L -C - -H "Authorization: Basic $AUTH" -o /content/test.zip.007 "https://www.kaggle.com/api/v1/competitions/data/download/diabetic-retinopathy-detection/test.zip.007"

# !curl -L -C - -H "Authorization: Basic $AUTH" -o /content/train.zip.001 "https://www.kaggle.com/api/v1/competitions/data/download/diabetic-retinopathy-detection/train.zip.001"
# !curl -L -C - -H "Authorization: Basic $AUTH" -o /content/train.zip.002 "https://www.kaggle.com/api/v1/competitions/data/download/diabetic-retinopathy-detection/train.zip.002"
# !curl -L -C - -H "Authorization: Basic $AUTH" -o /content/train.zip.003 "https://www.kaggle.com/api/v1/competitions/data/download/diabetic-retinopathy-detection/train.zip.003"
# !curl -L -C - -H "Authorization: Basic $AUTH" -o /content/train.zip.004 "https://www.kaggle.com/api/v1/competitions/data/download/diabetic-retinopathy-detection/train.zip.004"
# !curl -L -C - -H "Authorization: Basic $AUTH" -o /content/train.zip.005 "https://www.kaggle.com/api/v1/competitions/data/download/diabetic-retinopathy-detection/train.zip.005"

# %% [markdown]
# Move the dataset to the Google Drive storage

# %%
# !mv sample* /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped
# !mv test* /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped
# !mv train* /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped

# %%
# !ls -al /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped
# Out:
# total 86241227
# -rw------- 1 root root      83511 Dec 15  2019 sampleSubmission.csv.zip
# -rw------- 1 root root   10905224 Dec 15  2019 sample.zip
# drwx------ 2 root root       4096 Mar 11 03:37 test-unzipped-stage-1
# -rw------- 1 root root 8391158403 Mar 10 10:10 test.zip.001
# -rw------- 1 root root 8391159180 Mar 10 11:14 test.zip.002
# -rw------- 1 root root 8391159660 Mar 10 11:16 test.zip.003
# -rw------- 1 root root 8391159945 Mar 10 10:39 test.zip.004
# -rw------- 1 root root 8391159792 Mar 10 10:41 test.zip.005
# -rw------- 1 root root 8391159176 Mar 10 10:42 test.zip.006
# -rw------- 1 root root 2955860512 Mar 10 13:11 test.zip.007
# -rw------- 1 root root      71069 Dec 15  2019 trainLabels.csv.zip
# drwx------ 2 root root       4096 Mar 11 03:37 train-unzipped-stage-1
# -rw------- 1 root root 8391159087 Mar 10 10:57 train.zip.001
# -rw------- 1 root root 8391159780 Mar 10 10:59 train.zip.002
# -rw------- 1 root root 8391160349 Mar 10 11:01 train.zip.003
# ...

# %% [markdown]
# Extract small files directly within the Google Drive mount

# %%
# !unzip -q "/content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/sample.zip" -d "/content/drive/MyDrive/cmm704-data-mining/question-1/datasets/sample"
# !unzip -q "/content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/sampleSubmission.csv.zip" -d "/content/drive/MyDrive/cmm704-data-mining/question-1/datasets/sampleSubmission.csv"
# !unzip -q "/content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/trainLabels.csv.zip" -d "/content/drive/MyDrive/cmm704-data-mining/question-1/datasets/trainLabels.csv"

# %% [markdown]
# Extract large files directly within Google Drive mount(Not successful due to slow performance and potential I/O errors, as Drive is mounted in Google Colab via a FUSE-based (Filesystem in Userspace) network filesystem rather than a local disk)

# %%
# !7z x /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/test.zip.001 -o/content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/test-unzipped-stage-1
# !7z x /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/test.zip.002 -o/content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/test-unzipped-stage-1
# !7z x /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/test.zip.003 -o/content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/test-unzipped-stage-1
# !7z x /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/test.zip.004 -o/content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/test-unzipped-stage-1
# !7z x /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/test.zip.005 -o/content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/test-unzipped-stage-1
# !7z x /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/test.zip.006 -o/content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/test-unzipped-stage-1
# !7z x /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/test.zip.007 -o/content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/test-unzipped-stage-1

# !7z x /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/train.zip.001 -o/content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/train-unzipped-stage-1
# !7z x /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/train.zip.002 -o/content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/train-unzipped-stage-1
# !7z x /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/train.zip.003 -o/content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/train-unzipped-stage-1
# !7z x /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/train.zip.004 -o/content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/train-unzipped-stage-1
# !7z x /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/train.zip.005 -o/content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/train-unzipped-stage-1

# %% [markdown]
# Copy the compressed dataset files to the Google Colab VM local storage to accelerate the extraction process

# %%
# !rsync -ah --progress /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/test-unzipped-stage-1 /content
# !rsync -ah --progress /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/zipped/train-unzipped-stage-1 /content
# Out:
# sending incremental file list
# test-unzipped-stage-1/
# test-unzipped-stage-1/test.zip.001
#           8.39G 100%   63.14MB/s    0:02:06 (xfr#1, to-chk=6/8)
# test-unzipped-stage-1/test.zip.002
#           8.39G 100%   45.70MB/s    0:02:55 (xfr#2, to-chk=5/8)
# test-unzipped-stage-1/test.zip.003
#           8.39G 100%   49.84MB/s    0:02:40 (xfr#3, to-chk=4/8)
# test-unzipped-stage-1/test.zip.004
#           8.39G 100%   52.41MB/s    0:02:32 (xfr#4, to-chk=3/8)
# test-unzipped-stage-1/test.zip.005
#           8.39G 100%   49.77MB/s    0:02:40 (xfr#5, to-chk=2/8)
# test-unzipped-stage-1/test.zip.006
#           8.39G 100%   57.44MB/s    0:02:19 (xfr#6, to-chk=1/8)
# test-unzipped-stage-1/test.zip.007
#           2.96G 100%   67.83MB/s    0:00:41 (xfr#7, to-chk=0/8)

# %% [markdown]
# Extract the file list from the test zip archive

# %%
# !7z l /content/test-unzipped-stage-1/test.zip.001 | grep -F "test/" | awk '{$1=$2=$3=$4=$5=""; print $0}' | sed 's/^ *//' > /content/test.zip.files.txt

# %%
# !cat /content/test.zip.files.txt | wc -l
# Out:
# 53576

# %% [markdown]
# Partition train zip archive file list to fit within the storage limits of the Google Colab runtime during each extraction process

# %%
# !sed -n '1,10000p' /content/test.zip.files.txt > /content/test.zip.files.1.txt
# !sed -n '10001,20000p' /content/test.zip.files.txt > /content/test.zip.files.2.txt
# !sed -n '20001,30000p' /content/test.zip.files.txt > /content/test.zip.files.3.txt
# !sed -n '30001,40000p' /content/test.zip.files.txt > /content/test.zip.files.4.txt
# !sed -n '40001,50000p' /content/test.zip.files.txt > /content/test.zip.files.5.txt
# !sed -n '50001,$p' /content/test.zip.files.txt > /content/test.zip.files.6.txt

# %%
# !cat /content/test.zip.files.1.txt | wc -l
# !cat /content/test.zip.files.2.txt | wc -l
# !cat /content/test.zip.files.3.txt | wc -l
# !cat /content/test.zip.files.4.txt | wc -l
# !cat /content/test.zip.files.5.txt | wc -l
# !cat /content/test.zip.files.6.txt | wc -l
# Out:
# 10000
# 10000
# 10000
# 10000
# 10000
# 3576

# %% [markdown]
# Extract the partitioned portions of the test and train zip files

# %%
# !7z x /content/test-unzipped-stage-1/test.zip.001 @/content/test.zip.files.1.txt -o/content
# !7z x /content/test-unzipped-stage-1/test.zip.001 @/content/test.zip.files.2.txt -o/content
# !7z x /content/test-unzipped-stage-1/test.zip.001 @/content/test.zip.files.3.txt -o/content
# !7z x /content/test-unzipped-stage-1/test.zip.001 @/content/test.zip.files.4.txt -o/content
# !7z x /content/test-unzipped-stage-1/test.zip.001 @/content/test.zip.files.5.txt -o/content
# !7z x /content/test-unzipped-stage-1/test.zip.001 @/content/test.zip.files.6.txt -o/content

# !7z x /content/train-unzipped-stage-1/train.zip.001 -o/content
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 8388608000 bytes (8000 MiB)
#
# Extracting archive: /content/test-unzipped-stage-1/test.zip.001
# --
# Path = /content/test-unzipped-stage-1/test.zip.001
# Type = Split
# Physical Size = 8388608000
# Volumes = 7
# Total Physical Size = 53289598430
# ----
# Path = test.zip
# Size = 53289598430
# --
# Path = test.zip
# Type = zip
# Physical Size = 53289598430
# 64-bit = +
#
# Everything is Ok
#
# Files: 3576
# Size:       3890886997
# Compressed: 53289598430

# %% [markdown]
# Copy the extracted dataset files back to Google Drive using the cp command, chosen for its lightweight nature and faster performance compared to rsync when handling a large number of files

# %%
# !cp -r /content/test /content/drive/MyDrive/cmm704-data-mining/question-1/datasets
# !cp -r /content/train /content/drive/MyDrive/cmm704-data-mining/question-1/datasets
# Out:
# cp: cannot stat '/content/drive/MyDrive/cmm704-data-mining/question-1/datasets/test/7289_left.jpeg': Input/output error

# %%
# !ls /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/test | wc -l
# !ls /content/drive/MyDrive/cmm704-data-mining/question-1/datasets/train | wc -l
# Out:
# 53575

# %% [markdown]
# The extraction process was performed in this manner due to limited RAM and storage available on the Google Colab free tier
